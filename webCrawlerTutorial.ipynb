# %%
import requests
from bs4 import BeautifulSoup
import csv
import time

keyDict = ['접수마감', '지원기간', '행사일정', '일시', '신청기간', '접수 기간', '접수기간', '모집기간']

links = []
boardNums = []
titles = []
components = []

def collectInfo(url):
    maxNum = checkMaxPages(url)
    setFeatureNames(features)
    spider(url, int(maxNum))

def checkMaxPages(url):
    webPage = requests.get(url)
    soup = BeautifulSoup(webPage.text, 'lxml')
    pageLists = soup.find('ul', 'pagination')
    temp = pageLists.find_all('li')
    maxNum = temp[-2].get_text().strip()
    
    return maxNum

def spider(url, max_pages):
    page = 1
    url = url + "?page="
    while page <= max_pages:
        try:
            web = requests.get(url + str(page))
        except:
            time.sleep(300)
            web = requests.get(url + str(page))
#         with requests.Session() as sess:
#             web = sess.get(url + str(page))
#             sess.cookies.clear()
        webPage = BeautifulSoup(web.text, 'lxml')
        getBoardNumber(webPage)
        getBoardTitles(webPage)
        getBoardLinks(webPage)
        for i in links:
            board = requests.get(i)
            content = BeautifulSoup(board.text, 'lxml')
            content = content.find('td', 'border_bottom board_content')
            extractWithKeyword(content)
#         print(links)
#         print(titles)
#         print(components)
#         print(boardNums)
        dataToFile(titles, components)
        links.clear()
        titles.clear()
        boardNums.clear()
        components.clear()
        print("page " + str(page) + " complete!")
        page += 1

def getBoardTitles(page):
    for i in page.select('tr > td > a'):
        titles.append(i.get_text().strip())

def getBoardLinks(page):
    for i in page.select('tr > td > a'):
        links.append(i['href'])

def getBoardNumber(page):
    cnt = 0
    for i in page.find_all('td', 'border_bottom txt_center b_num'):
        if cnt % 2 == 0:
            boardNums.append(i.get_text().strip())
        cnt += 1

def extractWithKeyword(contents):
    for i in keyDict:
        component = contents.find(text = lambda t: t and i in t)
        if component:
            break
#     print(component)
#     print(type(component))
    components.append(component)

features = ["게시판 번호", "제목", "기간정보"]
FILE_NAME = "boardInfo.csv"

def setFeatureNames(features):
    with open(FILE_NAME, 'w', encoding='utf-8', newline='') as f:
        f_writer=  csv.writer(f)
        f_writer.writerow(features)
    
def dataToFile(titles, components):
    with open(FILE_NAME, 'a', encoding='utf-8', newline='') as f:
        f_writer = csv.writer(f)
        length = len(titles)
        for i in range(length):
            f_writer.writerow([boardNums[i], titles[i], components[i]])

# %%
collectInfo("http://www.jejunu.ac.kr/ara/notice")
# Out:
# page 1 complete!
# page 2 complete!
# page 3 complete!
# page 4 complete!
# page 5 complete!
# page 6 complete!
# page 7 complete!
# page 8 complete!
# page 9 complete!
# page 10 complete!
# page 11 complete!
# page 12 complete!
# page 13 complete!
# page 14 complete!
# page 15 complete!
# page 16 complete!
# page 17 complete!
# page 18 complete!
# page 19 complete!
# page 20 complete!
# page 21 complete!
# page 22 complete!
# page 23 complete!
# page 24 complete!
# page 25 complete!
# page 26 complete!
# page 27 complete!
# page 28 complete!
# page 29 complete!
# page 30 complete!
# page 31 complete!
# page 32 complete!
# page 33 complete!
# page 34 complete!
# page 35 complete!
# page 36 complete!
# page 37 complete!
# page 38 complete!
# page 39 complete!
# page 40 complete!
# page 41 complete!
# page 42 complete!
# page 43 complete!
# page 44 complete!
# page 45 complete!
# page 46 complete!
# page 47 complete!
# page 48 complete!
# page 49 complete!
# page 50 complete!
# page 51 complete!
# page 52 complete!
# page 53 complete!
# page 54 complete!
# page 55 complete!
# page 56 complete!
# page 57 complete!
# page 58 complete!
# page 59 complete!
# page 60 complete!
# page 61 complete!
# page 62 complete!
# page 63 complete!
# page 64 complete!
# page 65 complete!
# page 66 complete!
# page 67 complete!
# page 68 complete!
# page 69 complete!
# page 70 complete!
# page 71 complete!
# page 72 complete!
# page 73 complete!
# page 74 complete!
# page 75 complete!
# page 76 complete!
# page 77 complete!
# page 78 complete!
# page 79 complete!
# page 80 complete!
# page 81 complete!
# page 82 complete!
# page 83 complete!
# page 84 complete!
# page 85 complete!
# page 86 complete!
# page 87 complete!
# page 88 complete!
# page 89 complete!
# page 90 complete!
# page 91 complete!
# page 92 complete!
# page 93 complete!
# page 94 complete!
# page 95 complete!
# page 96 complete!
# page 97 complete!
# page 98 complete!
# page 99 complete!
# page 100 complete!
# page 101 complete!
# page 102 complete!
# page 103 complete!
# page 104 complete!
# page 105 complete!
# page 106 complete!
# page 107 complete!
# page 108 complete!
# page 109 complete!
# page 110 complete!
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     140             conn = connection.create_connection(
# --> 141                 (self.host, self.port), self.timeout, **extra_kw)
#     142
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      82     if err is not None:
# ---> 83         raise err
#      84
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      72                 sock.bind(source_address)
# ---> 73             sock.connect(sa)
#      74             return sock
#
# TimeoutError: [WinError 10060] 연결된 구성원으로부터 응답이 없어 연결하지 못했거나, 호스트로부터 응답이 없어 연결이 끊어졌습니다
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     356         else:
# --> 357             conn.request(method, url, **httplib_request_kw)
#     358
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1284             body = _encode(body, 'body')
# -> 1285         self.endheaders(body, encode_chunked=encode_chunked)
#    1286
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1233             raise CannotSendHeader()
# -> 1234         self._send_output(message_body, encode_chunked=encode_chunked)
#    1235
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\http\client.py in send(self, data)
#     963             if self.auto_open:
# --> 964                 self.connect()
#     965             else:
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\urllib3\connection.py in connect(self)
#     165     def connect(self):
# --> 166         conn = self._new_conn()
#     167         self._prepare_conn(conn)
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     149             raise NewConnectionError(
# --> 150                 self, "Failed to establish a new connection: %s" % e)
#     151
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x000001E836149DD8>: Failed to establish a new connection: [WinError 10060] 연결된 구성원으로부터 응답이 없어 연결하지 못했거나, 호스트로부터 응답이 없어 연결이 끊어졌습니다
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     638             retries = retries.increment(method, url, error=e, _pool=self,
# --> 639                                         _stacktrace=sys.exc_info()[2])
#     640             retries.sleep()
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     387         if new_retry.is_exhausted():
# --> 388             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     389
#
# MaxRetryError: HTTPConnectionPool(host='www.jejunu.ac.kr', port=80): Max retries exceeded with url: /ara/notice/15203256693299?page=111 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000001E836149DD8>: Failed to establish a new connection: [WinError 10060] 연결된 구성원으로부터 응답이 없어 연결하지 못했거나, 호스트로부터 응답이 없어 연결이 끊어졌습니다',))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-2-9a072dc6afb4> in <module>()
# ----> 1 collectInfo("http://www.jejunu.ac.kr/ara/notice")
#
# <ipython-input-1-c08b88ed4fc5> in collectInfo(url)
#      14     maxNum = checkMaxPages(url)
#      15     setFeatureNames(features)
# ---> 16     spider(url, int(maxNum))
#      17
#      18 def checkMaxPages(url):
#
# <ipython-input-1-c08b88ed4fc5> in spider(url, max_pages)
#      42         getBoardLinks(webPage)
#      43         for i in links:
# ---> 44             board = requests.get(i)
#      45             content = BeautifulSoup(board.text, 'lxml')
#      46             content = content.find('td', 'border_bottom board_content')
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPConnectionPool(host='www.jejunu.ac.kr', port=80): Max retries exceeded with url: /ara/notice/15203256693299?page=111 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000001E836149DD8>: Failed to establish a new connection: [WinError 10060] 연결된 구성원으로부터 응답이 없어 연결하지 못했거나, 호스트로부터 응답이 없어 연결이 끊어졌습니다',))
